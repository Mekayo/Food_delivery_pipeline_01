# %%
import pandas as pd
import numpy as np
import sklearn as sk

# %%
df=pd.read_csv(r"C:\Users\monst\Desktop\Food_Delivery_01\data\curated\orders_clean.csv")

# %%
df.head()
# Out:
#      order_id            name     amenity   cuisine       place        lat  \
# 0  1431156028      Citco Cafe  restaurant   unknown     unknown  30.750353
# 1  1819752762  Student Centre   fast_food  regional     unknown  30.762265
# 2  2434546249        Domino's   fast_food     pizza  Chandigarh  30.740520
# 3  2434552646             KFC   fast_food   chicken  Chandigarh  30.739961
# 4  2623400919       Pizza Hut  restaurant     pizza  Chandigarh  30.754707
#
#          lon
# 0  76.787520
# 1  76.769824
# 2  76.797231
# 3  76.792042
# 4  76.769886

# %%
CITY_CENTER_LAT = 30.7333
CITY_CENTER_LON = 76.7794

df["customer_lat"]=CITY_CENTER_LAT
df["customer_lan"]=CITY_CENTER_LON
df.head()
# Out:
#      order_id            name     amenity   cuisine       place        lat  \
# 0  1431156028      Citco Cafe  restaurant   unknown     unknown  30.750353
# 1  1819752762  Student Centre   fast_food  regional     unknown  30.762265
# 2  2434546249        Domino's   fast_food     pizza  Chandigarh  30.740520
# 3  2434552646             KFC   fast_food   chicken  Chandigarh  30.739961
# 4  2623400919       Pizza Hut  restaurant     pizza  Chandigarh  30.754707
#
#          lon  customer_lat  customer_lan
# 0  76.787520       30.7333       76.7794
# 1  76.769824       30.7333       76.7794
# 2  76.797231       30.7333       76.7794
# 3  76.792042       30.7333       76.7794
# 4  76.769886       30.7333       76.7794

# %%
from math import radians, cos, sin, asin, sqrt

# %%
def haversine(lat1, lon1, lat2, lon2):
    R = 6371  # Earth radius in km
    lat1, lon1, lat2, lon2 = map(np.radians, [lat1, lon1, lat2, lon2])
    dlat = lat2 - lat1
    dlon = lon2 - lon1

    a = np.sin(dlat / 2)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon / 2)**2
    c = 2 * np.arcsin(np.sqrt(a))
    return R * c

# %%
df["distance"]= haversine(
    df["lat"],df["lon"],df["customer_lat"],df["customer_lan"]
)

# %%
df.to_csv(r"C:\Users\monst\Desktop\Food_Delivery_01\data\curated\orders_featured.csv",index=False)

# %%
df.head(20)
# Out:
#       order_id                          name     amenity  \
# 0   1431156028                    Citco Cafe  restaurant
# 1   1819752762                Student Centre   fast_food
# 2   2434546249                      Domino's   fast_food
# 3   2434552646                           KFC   fast_food
# 4   2623400919                     Pizza Hut  restaurant
# 5   2623402079                       Gopal's  restaurant
# 6   2623402294                      La Pinoz        cafe
# 7   2623403244                        Talwar  restaurant
# 8   2623403423                      Domino's   fast_food
# 9   3185953504                  1113;5 Yesss   fast_food
# 10  3476116193                   Roll corner  restaurant
# 11  3595994933              Backpackers Cafe  restaurant
# 12  4214695189                 Old Pal Dhaba  restaurant
# 13  4214699191              Virgin Courtyard  restaurant
# 14  4214699590  Aja Fresh, Grilled & Healthy  restaurant
# ...
